# %%
import darshan as dardarbinks
import seaborn as sb
import pandas as pd
import dask.dataframe as dd
import darshan.backend.cffi_backend as backend

dardarbinks.enable_experimental()

from argparse import ArgumentParser
from darshan_helpers import load_dataframe, load_dataframe_dxt
from darshan_helpers import METADATA_COLUMNS

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive
from IPython.display import display

special_groupings = [
    "operation_types",
    "posix_v_stdio"
]

def args(workdir, exp_type, exp_name, limit_runs, operations):
    return (workdir, exp_type, exp_name, limit_runs, operations)

arguments=interactive(args, workdir="../../data/exps", exp_type=["weak_scaling", "strong_scaling"], exp_name=["general", "phases", "sharedfs"], limit_runs=True, continuous_update=False, operations=["read", "write"])
display(arguments)
# Out:
# interactive(children=(Text(value='../../data/exps', description='workdir'), Dropdown(description='exp_type', o…

# %%
def sample_df(df):
    slimmed_df = df.sample(frac=0.1)
    # print(slimmed_df)
    # slimmed_df = df
    return slimmed_df

# load data
# print(arguments.result)
darshan_data_frames = load_dataframe_dxt(arguments.result[0], arguments.result[1], arguments.result[2], arguments.result[3], dxt_operations=["read", "write"], analysis_func=sample_df)
# print(darshan_data_frames)
# darshan_data_frames.to_parquet("dxt_chunks/darshan_data_frames.parquet", name_function=lambda x: f"dxt_{x}.parquet")
darshan_data_frames
# Out:
# Parameters:
# workdir:  ../../data/exps
# experiment_type:  strong_scaling
# experiment_name:  phases
# limit_runs:  True
# Processing log 1 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 2 / 1746
# Processing log 3 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 4 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 5 / 1746
# Configuration change detected, concatenating data frames...
# Running callable if available...
#                           id operation      offset  length    start_time  \
# 78983   16534718481442541994     write   168666489    1632  14789.569601
# 198452  16534718481442541994     write   425721341     588  36389.793801
# 86651   16740568766787747713      read  2417488300  320577  10142.794387
# 80684   16534718481442541994     write   172982546     787  14789.582315
# 201134   7452578327298260666      read   394833184    4012   2328.897728
# ...                      ...       ...         ...     ...           ...
# 355818   7452578327298260666      read   991961876    3865   5810.302746
# 85744   16740568766787747713      read  2400336992     907  10028.179149
# 538602   7452578327298260666      read  1697547565    3996   9945.930918
# 229671  16534718481442541994     write   492779162     619  42082.928932
# 20103   16740568766787747713      read   480946103    4476   1962.038809
#
#             end_time  max_events  nprocs container option run  \
# 78983   14789.569603          -1       1      none    500   1
# 198452  36389.793807          -1       1      none    500   1
# 86651   10142.794835          -1       1      none    500   1
# 80684   14789.582317          -1       1      none    500   1
# 201134   2328.897776          -1       1      none    500   1
# ...              ...         ...     ...       ...    ...  ..
# 355818   5810.302777          -1       1      none    500   1
# 85744   10028.179150          -1       1      none    500   1
# 538602   9945.930946          -1       1      none    500   1
# 229671  42082.928934          -1       1      none    500   1
# 20103    1962.038810          -1       1      none    500   1
#
#                                                 file_name         worker
# 78983   /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 198452  /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 86651   /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...       worker_0
# 80684   /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 201134  /tmp/wkwiecin/strong_scaling/general/1/none/fa...       worker_0
# ...                                                   ...            ...
# 355818  /tmp/wkwiecin/strong_scaling/general/1/none/fa...       worker_0
# 85744   /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...       worker_0
# 538602  /tmp/wkwiecin/strong_scaling/general/1/none/fa...       worker_0
# 229671  /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 20103   /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...       worker_0
#
# [93513 rows x 13 columns]
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 6 / 1746
# Processing log 7 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 8 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 9 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 10 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 11 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 12 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 13 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 14 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 15 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 16 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 17 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 18 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 19 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 20 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 21 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 22 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 23 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 24 / 1746
# Configuration change detected, concatenating data frames...
# Running callable if available...
#                           id operation      offset length   start_time  \
# 176896   4877360380226026954     write   120554205    411   761.086475
# 38958   11946695458830863258      read    46341255   3689   281.631619
# 293216   4877360380226026954     write   186066621    401  1066.945250
# 76286   15929895014118001762      read   165327815   3902   928.756061
# 29352   15702831653135039615      read    14588585   3506    96.110001
# ...                      ...       ...         ...    ...          ...
# 18724   16740568766787747713      read  8406099733   5952  2820.678360
# 98415    7756093457492080206      read   257433364   3692  1422.183309
# 34693   15929895014118001762      read    17244520   3532   126.580777
# 77424    7346552891321768891      read   186184958   3689  1047.705561
# 91069   11946695458830863258      read   231876862   3518  1266.239026
#
#            end_time  max_events  nprocs  container option run  \
# 176896   761.086477          -1      16  apptainer    100   1
# 38958    281.631644          -1      16  apptainer    100   1
# 293216  1066.945251          -1      16  apptainer    100   1
# 76286    928.756201          -1      16  apptainer    100   1
# 29352     96.110044          -1      16  apptainer    100   1
# ...             ...         ...     ...        ...    ...  ..
# 18724   2820.678362          -1      16  apptainer    100   1
# 98415   1422.183324          -1      16  apptainer    100   1
# 34693    126.580811          -1      16  apptainer    100   1
# 77424   1047.705585          -1      16  apptainer    100   1
# 91069   1266.239048          -1      16  apptainer    100   1
#
#                                                 file_name         worker
# 176896  /tmp/wkwiecin/strong_scaling/16/apptainer/100/...  shared_writer
# 38958   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...       worker_0
# 293216  /tmp/wkwiecin/strong_scaling/16/apptainer/100/...  shared_writer
# 76286   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...      worker_14
# 29352   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...      worker_13
# ...                                                   ...            ...
# 18724   /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...       worker_1
# 98415   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...       worker_7
# 34693   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...      worker_14
# 77424   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...       worker_6
# 91069   /tmp/wkwiecin/strong_scaling/16/apptainer/100/...       worker_0
#
# [422952 rows x 13 columns]
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 25 / 1746
# Processing log 26 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 27 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 28 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 29 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 30 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 31 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 32 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 33 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 34 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 35 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 36 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 37 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 38 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 39 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 40 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 41 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 42 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 43 / 1746
# Configuration change detected, concatenating data frames...
# Running callable if available...
#                           id operation      offset length   start_time  \
# 138730   4187345985253481727      read   400601887   3973  2183.813101
# 164868   7836650556846667087      read   493584920   3376  2678.998671
# 57826    4014270670122379710      read   109983527   3376   618.088321
# 172590   3963378655991036052      read   521101945   3355  2846.780187
# 129068   3168323735951469133      read   369886646   3569  2052.540484
# ...                      ...       ...         ...    ...          ...
# 72806   14349524225460277459      read   166815816   3391   934.090314
# 55319    3963378655991036052      read   104133435   3502   589.843857
# 24277    3710461203408548777      read       38503   3551  3950.517603
# 85815    5513546250303318738      read   209380490   3524  1149.747909
# 6961    16740568766787747713      read  3030359153    855  1044.583668
#
#            end_time  max_events  nprocs  container option run  \
# 138730  2183.813131          -1      16  apptainer   1000   1
# 164868  2678.998692          -1      16  apptainer   1000   1
# 57826    618.088377          -1      16  apptainer   1000   1
# 172590  2846.780221          -1      16  apptainer   1000   1
# 129068  2052.540509          -1      16  apptainer   1000   1
# ...             ...         ...     ...        ...    ...  ..
# 72806    934.090357          -1      16  apptainer   1000   1
# 55319    589.843925          -1      16  apptainer   1000   1
# 24277   3950.517633          -1      16  apptainer   1000   1
# 85815   1149.747933          -1      16  apptainer   1000   1
# 6961    1044.583671          -1      16  apptainer   1000   1
#
#                                                 file_name     worker
# 138730  /tmp/wkwiecin/strong_scaling/16/apptainer/1000...   worker_9
# 164868  /tmp/wkwiecin/strong_scaling/16/apptainer/1000...  worker_10
# 57826   /tmp/wkwiecin/strong_scaling/16/apptainer/1000...   worker_0
# 172590  /tmp/wkwiecin/strong_scaling/16/apptainer/1000...  worker_11
# 129068  /tmp/wkwiecin/strong_scaling/16/apptainer/1000...   worker_2
# ...                                                   ...        ...
# 72806   /tmp/wkwiecin/strong_scaling/16/apptainer/1000...  worker_14
# 55319   /tmp/wkwiecin/strong_scaling/16/apptainer/1000...  worker_11
# 24277   /tmp/wkwiecin/strong_scaling/16/apptainer/1000...   worker_7
# 85815   /tmp/wkwiecin/strong_scaling/16/apptainer/1000...   worker_4
# 6961    /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...   worker_5
#
# [395387 rows x 13 columns]
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 44 / 1746
# Processing log 45 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 46 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 47 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 48 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 49 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 50 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 51 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 52 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 53 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 54 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 55 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 56 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 57 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 58 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 59 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 60 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 61 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 62 / 1746
# Configuration change detected, concatenating data frames...
# Running callable if available...
#                           id operation      offset length   start_time  \
# 80686    4225681459383964977      read   194247717   3689  1070.564049
# 122952   6117377180151502836      read   344830744   3502  1873.515147
# 65112    4225681459383964977      read   138915868   3364   766.665507
# 109189  16027554023061760787      read   296042233   3548  1658.188904
# 48456   17279221499569997953      read    79677578   3982   433.075206
# ...                      ...       ...         ...    ...          ...
# 109691  15958691043507299209      read   297928525   3692  1623.796158
# 147146   7939892673033072111      read   427180039   3503  2296.857895
# 8373    16740568766787747713      read  3570216003    554   984.786077
# 19904    7538332296747688662     write    34377225    207   620.440663
# 117116   1538466705084729961      read   323955757   3358  1750.559819
#
#            end_time  max_events  nprocs  container option run  \
# 80686   1070.564065          -1      16  apptainer    500   1
# 122952  1873.515171          -1      16  apptainer    500   1
# 65112    766.665529          -1      16  apptainer    500   1
# 109189  1658.188936          -1      16  apptainer    500   1
# 48456    433.075233          -1      16  apptainer    500   1
# ...             ...         ...     ...        ...    ...  ..
# 109691  1623.796174          -1      16  apptainer    500   1
# 147146  2296.857918          -1      16  apptainer    500   1
# 8373     984.786081          -1      16  apptainer    500   1
# 19904    620.440664          -1      16  apptainer    500   1
# 117116  1750.559867          -1      16  apptainer    500   1
#
#                                                 file_name         worker
# 80686   /tmp/wkwiecin/experiment/strong_scaling/genera...       worker_8
# 122952  /tmp/wkwiecin/experiment/strong_scaling/genera...       worker_1
# 65112   /tmp/wkwiecin/experiment/strong_scaling/genera...       worker_8
# 109189  /tmp/wkwiecin/experiment/strong_scaling/genera...       worker_2
# 48456   /tmp/wkwiecin/experiment/strong_scaling/genera...       worker_4
# ...                                                   ...            ...
# 109691  /tmp/wkwiecin/experiment/strong_scaling/genera...       worker_5
# 147146  /tmp/wkwiecin/experiment/strong_scaling/genera...      worker_15
# 8373    /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...       worker_0
# 19904   /tmp/wkwiecin/experiment/strong_scaling/genera...  shared_writer
# 117116  /tmp/wkwiecin/experiment/strong_scaling/genera...      worker_12
#
# [336458 rows x 13 columns]
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 63 / 1746
# Processing log 64 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 65 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 66 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 67 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 68 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 69 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 70 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 71 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 72 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 73 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 74 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 75 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 76 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 77 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 78 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 79 / 1746
# ...
# 49315   /tmp/wkwiecin/strong_scaling/8/podman/false/1/...       worker_1
# 51767   /tmp/wkwiecin/strong_scaling/8/podman/false/1/...       worker_6
#
# [319015 rows x 13 columns]
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1726 / 1746
# Processing log 1727 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1728 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1729 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1730 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1731 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1732 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1733 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1734 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1735 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1736 / 1746
# Configuration change detected, concatenating data frames...
# Running callable if available...
#                           id operation     offset length   start_time  \
# 52883   11442992278103312793      read    7051357   3360  6234.307511
# 98153    9335688119120198877      read  161450789   3544   889.465103
# 258873   2355498824311870408     write  156366226    252  1344.722311
# 118557    624860339748291015      read  240249626   3370  1315.577460
# 179821   6558857568588101242      read  464366280   3714  2513.249393
# ...                      ...       ...        ...    ...          ...
# 300430   1698830934158510534      read  897148951   3514  4854.587709
# 178421  18207477047999977545      read  436177340   3484  2357.656738
# 349052   2355498824311870408     write  208158334    354  1785.496499
# 171190  14544763797221096243      read  457227285   3380  2494.791941
# 62294    1698830934158510534      read   49692398   3514   277.920893
#
#            end_time  max_events  nprocs container option run  \
# 52883   6234.307567          -1       8   shifter    100   1
# 98153    889.465125          -1       8   shifter    100   1
# 258873  1344.722312          -1       8   shifter    100   1
# 118557  1315.577488          -1       8   shifter    100   1
# 179821  2513.249416          -1       8   shifter    100   1
# ...             ...         ...     ...       ...    ...  ..
# 300430  4854.587729          -1       8   shifter    100   1
# 178421  2357.656761          -1       8   shifter    100   1
# 349052  1785.496500          -1       8   shifter    100   1
# 171190  2494.791991          -1       8   shifter    100   1
# 62294    277.920915          -1       8   shifter    100   1
#
#                                                 file_name         worker
# 52883   /tmp/wkwiecin/strong_scaling/8/shifter/100/1/F...           main
# 98153   /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_0
# 258873  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...  shared_writer
# 118557  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_6
# 179821  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_5
# ...                                                   ...            ...
# 300430  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_2
# 178421  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_7
# 349052  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...  shared_writer
# 171190  /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_1
# 62294   /tmp/wkwiecin/strong_scaling/8/shifter/100/1/a...       worker_2
#
# [361743 rows x 13 columns]
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1737 / 1746
# Processing log 1738 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1739 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1740 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1741 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1742 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1743 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1744 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1745 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Processing log 1746 / 1746
# /home/wkwiecinski/projects/DerivationExperiments/analysis/darshan_helpers.py:146: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dxt_df = pd.concat([dxt_df, data['read_segments']], ignore_index=True)
# Logs loaded
#                           id operation      offset  length    start_time  \
# 78983   16534718481442541994     write   168666489    1632  14789.569601
# 198452  16534718481442541994     write   425721341     588  36389.793801
# 86651   16740568766787747713      read  2417488300  320577  10142.794387
# 80684   16534718481442541994     write   172982546     787  14789.582315
# 201134   7452578327298260666      read   394833184    4012   2328.897728
# ...                      ...       ...         ...     ...           ...
# 169725   9460289712659356103      read     8164819    3360   7596.754546
# 169726   9460289712659356103      read     8168179       0   7596.754591
# 169727   9460289712659356103      read     8168179    1595   7596.754602
# 169728   9460289712659356103      read     8169774       0   7596.754627
# 169729   7217067890746397502     write           0    2015   7596.754759
#
#             end_time  max_events  nprocs container option run  \
# 78983   14789.569603          -1       1      none    500   1
# 198452  36389.793807          -1       1      none    500   1
# 86651   10142.794835          -1       1      none    500   1
# 80684   14789.582317          -1       1      none    500   1
# 201134   2328.897776          -1       1      none    500   1
# ...              ...         ...     ...       ...    ...  ..
# 169725   7596.754589          -1       8   shifter   1000   1
# 169726   7596.754592          -1       8   shifter   1000   1
# 169727   7596.754623          -1       8   shifter   1000   1
# 169728   7596.754627          -1       8   shifter   1000   1
# 169729   7596.754765          -1       8   shifter   1000   1
#
#                                                 file_name         worker
# 78983   /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 198452  /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 86651   /cvmfs/atlas-nightlies.cern.ch/repo/data/data-...       worker_0
# 80684   /tmp/wkwiecin/strong_scaling/general/1/none/fa...  shared_writer
# 201134  /tmp/wkwiecin/strong_scaling/general/1/none/fa...       worker_0
# ...                                                   ...            ...
# 169725  /tmp/wkwiecin/strong_scaling/8/shifter/1000/1/...  shared_writer
# 169726  /tmp/wkwiecin/strong_scaling/8/shifter/1000/1/...  shared_writer
# 169727  /tmp/wkwiecin/strong_scaling/8/shifter/1000/1/...  shared_writer
# 169728  /tmp/wkwiecin/strong_scaling/8/shifter/1000/1/...  shared_writer
# 169729  /tmp/wkwiecin/strong_scaling/8/shifter/1000/1/...  shared_writer
#
# [34422056 rows x 13 columns]

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt


color_map = {
    "apptainer": "#45B6EB",
    "none": "#E7BB42",
    "podman": "#62B35F",
    "shifter": "#FF33A8"
}

SCALING=' '.join(arguments.result[1].split('_'))
nprocs=32
operation="write"


shared_writer_starts = darshan_data_frames[(darshan_data_frames["file_name"].str.endswith("DAOD_PHYSLITE.pool.root.1")) & (darshan_data_frames["worker"] == "shared_writer") & (darshan_data_frames["option"] != "250")].groupby(["nprocs", "container", "option"]).agg({"start_time": "min"}).reset_index() #sort_values(["nprocs", "container", "option", "start_time"]).reset_index() #
shared_writer_starts.rename(columns={"start_time": "learning_phase_begins"}, inplace=True)

fig,axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 6), sharex=False, sharey=False)
for idx,option in enumerate(["100", "500", "1000"]):
    # option_df = shared_writer_starts[shared_writer_starts["option"] == option]
    option_subset = darshan_data_frames[(darshan_data_frames["option"] == option) & (darshan_data_frames["nprocs"] == nprocs) & (darshan_data_frames["operation"] == operation)]
    option_subset["length (KB)"] = option_subset["length"] / 1024
    # shared_writer_starts[shared_writer_starts["option"] == option]
    # print(shared_writer_starts[shared_writer_starts["option"] == option])
    plot_df = pd.merge(option_subset, shared_writer_starts, on=["nprocs", "container", "option"], how="left")
    # print(plot_df)
    plot1 = sb.histplot(data=plot_df, x="start_time", hue="container", ax=axes[0][idx], label=option, color=color_map)
    plot1.set_title(f"{operation} operation distribution | auto-flush={option} | nprocs={nprocs}")

    plot2 = sb.histplot(data=plot_df, x="length (KB)", hue="container", multiple="dodge", bins=10, ax=axes[1][idx], log_scale=True, label=option, shrink=0.8, color=color_map)
    
    # print(plot_df)
    # print(plot_df.groupby("container").agg({"learning_phase_begins": "min"}).reset_index())
    for index, row in plot_df.groupby("container").agg({"learning_phase_begins": "min"}).reset_index().iterrows():
        # print(row)
        axes[0][idx].axvline(x=row["learning_phase_begins"], color=color_map[row["container"]], linestyle='--')
    # for sub_idx,start_time in enumerate(plot_df["learning_phase_begins"].unique()):
    #     # print(plot_d].unique())
    #     axes[0][idx].axvline(x=start_time, color='red', linestyle='--')

fig.suptitle(f"Auto-flush Configuration Comparison ({SCALING})")
# shared_writer_starts
# fig
# Out:
# /tmp/ipykernel_334529/2926849148.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   option_subset["length (KB)"] = option_subset["length"] / 1024
# /tmp/ipykernel_334529/2926849148.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   option_subset["length (KB)"] = option_subset["length"] / 1024
# /tmp/ipykernel_334529/2926849148.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   option_subset["length (KB)"] = option_subset["length"] / 1024
# Text(0.5, 0.98, 'Auto-flush Configuration Comparison (strong scaling)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

nprocs=32
# plot the write start_time distribution
write_frames = darshan_data_frames[darshan_data_frames["operation"] == "write"]
write_frames["length (KB)"] = write_frames["length"] / (1024)
write_frames = write_frames[write_frames["nprocs"] == nprocs]

# print(write_frames)

sb.set_theme(style="whitegrid")
time_plot = sb.histplot(data=write_frames, x="start_time", hue="container", bins='auto')
time_plot.set_title(f"Distribution of Writes for {nprocs} Processes")
plt.show()

size_plot = sb.histplot(data=write_frames, x="length (KB)", hue="container", multiple="dodge", bins=10, log_scale=True, shrink=0.8)
size_plot.set_title(f"Distribution of Write Sizes for {nprocs} Processes")
plt.show()

# throughput = sb.histplot(data=write_frames, x="length (KB)", hue="container", multiple="dodge", bins=10, log_scale=True, shrink=0.8)
# throughput.set_title("Distribution of Write Sizes for 32 Processes")
# plt.show()

# line_plot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 13
#      10 # print(write_frames)
#      12 sb.set_theme(style="whitegrid")
# ---> 13 time_plot = sb.histplot(data=write_frames, x="start_time", hue="container", bins='auto')
#      14 time_plot.set_title(f"Distribution of Writes for {nprocs} Processes")
#      15 plt.show()
#
# File ~/.ath_analysis/lib/python3.10/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File ~/.ath_analysis/lib/python3.10/site-packages/seaborn/distributions.py:665, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     658             line.sticky_edges.y[:] = sticky_y
#     660 if element == "bars" and "linewidth" not in plot_kws:
#     661
#     662     # Now we handle linewidth, which depends on the scaling of the plot
#     663
#     664     # We will base everything on the minimum bin width
# --> 665     hist_metadata = pd.concat([
#     666         # Use .items for generality over dict or df
#     667         h.index.to_frame() for _, h in histograms.items()
#     668     ]).reset_index(drop=True)
#     669     thin_bar_idx = hist_metadata["widths"].idxmin()
#     670     binwidth = hist_metadata.loc[thin_bar_idx, "widths"]
#
# File ~/.ath_analysis/lib/python3.10/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/.ath_analysis/lib/python3.10/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/.ath_analysis/lib/python3.10/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
darshan_data_frames = darshan_data_frames[(darshan_data_frames["nprocs"] >= 8) & (darshan_data_frames["nprocs"] < 128)]
darshan_data_frames
# Out:
#                          id operation     offset length   start_time  \
# 15707    404826347394862993      read    9718273   3512    64.386369
# 73004  15458478378626844237      read  216296509   3689  1200.586333
# 14320   3023343571058573835      read    8122803   3658    65.850554
# 27235  13249177646745992904      read   53833640   3526   314.218205
# 51889   1223479834734236532      read  141515699   3955   782.403279
# ...                     ...       ...        ...    ...          ...
# 69341   3722754645452674998      read    8172962   3360  1711.765894
# 69342   3722754645452674998      read    8176322      0  1711.765940
# 69343   3722754645452674998      read    8176322   1596  1711.765950
# 69344   3722754645452674998      read    8177918      0  1711.765978
# 69345   5886452460167630953     write          0   2024  1711.766137
#
#           end_time  max_events  nprocs  container option run         worker
# 15707    64.386399       16000      16  apptainer    100   1       worker_9
# 73004  1200.586349       16000      16  apptainer    100   1      worker_14
# 14320    65.850595       16000      16  apptainer    100   1       worker_1
# 27235   314.218231       16000      16  apptainer    100   1       worker_5
# 51889   782.403300       16000      16  apptainer    100   1      worker_11
# ...            ...         ...     ...        ...    ...  ..            ...
# 69341  1711.765938        8000       8    shifter   1000   1  shared_writer
# 69342  1711.765941        8000       8    shifter   1000   1  shared_writer
# 69343  1711.765975        8000       8    shifter   1000   1  shared_writer
# 69344  1711.765979        8000       8    shifter   1000   1  shared_writer
# 69345  1711.766144        8000       8    shifter   1000   1  shared_writer
#
# [11355165 rows x 12 columns]

# %%
import seaborn as sb

# df = darshan_data_frames.groupby(["nprocs", "container", "option", "operation"]).agg({"start_time": "min"})

for autoflush in darshan_data_frames["option"].unique():
    df = darshan_data_frames[darshan_data_frames["option"] == autoflush]
    grouped = df.groupby(["nprocs", "container", "operation", "worker"]).agg({"start_time": "min"})
    print(grouped)
    # print("Autoflush:", autoflush)
    # print(df)
# Out:
#                                            start_time
# nprocs container operation worker
# 8      apptainer read      evt_counter       0.512118
#                            main              0.057171
#                            shared_writer     0.657372
#                            worker_0          0.631000
#                            worker_1          0.544822
# ...                                               ...
# 64     none      write     worker_62        18.172102
#                            worker_63        20.533045
#                            worker_7       1466.793012
#                            worker_8          2.763414
#                            worker_9       1536.118643
#
# [629 rows x 1 columns]
#                                            start_time
# nprocs container operation worker
# 8      apptainer read      evt_counter       0.361372
#                            main              0.082266
#                            shared_writer     0.610293
#                            worker_0          0.553029
#                            worker_1          0.497297
# ...                                               ...
# 64     none      write     worker_62       348.283387
#                            worker_63      1129.244784
#                            worker_7          4.219794
#                            worker_8        563.779691
#                            worker_9         21.503789
#
# [630 rows x 1 columns]
#                                            start_time
# nprocs container operation worker
# 8      none      read      evt_counter       0.501229
#                            main              0.163075
#                            shared_writer     0.398273
#                            worker_0          0.530415
#                            worker_1          0.721687
# ...                                               ...
# 64     none      write     worker_62        15.121953
#                            worker_63       904.226682
#                            worker_7       2386.108277
#                            worker_8       2864.345974
#                            worker_9       2612.718846
#
# [290 rows x 1 columns]
#                                            start_time
# nprocs container operation worker
# 16     shifter   read      evt_counter       0.357892
#                            main              0.185871
#                            shared_writer     0.393483
#                            worker_0          0.667572
#                            worker_1          0.496974
#                            worker_10         1.066905
#                            worker_11         0.781868
#                            worker_12         0.850344
#                            worker_13         0.427931
#                            worker_14         0.397251
#                            worker_15         0.500596
#                            worker_2          0.642392
#                            worker_3          0.506871
#                            worker_4          0.880814
#                            worker_5          0.591152
#                            worker_6          0.894218
#                            worker_7          0.560531
#                            worker_8          0.975307
#                            worker_9          0.721499
#                  write     evt_counter       1.914736
#                            main              1.174452
#                            shared_writer   771.221845
#                            worker_0        410.571394
#                            worker_1        839.076296
#                            worker_10        11.811042
#                            worker_11         1.154477
#                            worker_12        10.712440
#                            worker_13       164.350296
#                            worker_14       358.734208
#                            worker_15        12.954196
#                            worker_2         13.823610
#                            worker_3        601.312266
#                            worker_4        848.840710
#                            worker_5       1446.572174
#                            worker_6        183.760504
#                            worker_7         14.040034
#                            worker_8       1029.950960
#                            worker_9        610.436929

# %%
import matplotlib.pyplot as plt
import seaborn as sb

sb.set_theme(style="whitegrid")
nprocs=64
# darshan_data_frames = darshan_data_frames[(darshan_data_frames["nprocs"] >= 8) & (darshan_data_frames["nprocs"] < 128)]
darshan_data_frames.drop(columns=["operation", "id", "max_events"], inplace=True)
# darshan_data_frames["length"] = darshan_data_frames["length"] / 1024

# plot the write start_time distribution
# read_frames = df[(df["operation"] == "read") & (df["nprocs"] == nprocs)]
# read_frames["length (KB)"] = read_frames["length"] / 1024

# write_frames = ...
# plot = sb.histplot(data=darshan_data_frames[darshan_data_frames["nprocs"] == nprocs], x="start_time", hue="container", bins='auto', kde=True)
# plot.set_title(f"Distribution of Reads for {nprocs} Procs")
# plt.show()

# read_sizes = sb.histplot(data=read_frames, x="length (KB)", hue="container", bins=10, log_scale=True, multiple="dodge", shrink=0.8)
# read_sizes.set_title(f"Distribution of Read sizes for {nprocs} Procs")
# plt.show()
darshan_data_frames
# Out:
# /tmp/ipykernel_402519/1672003492.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   darshan_data_frames.drop(columns=["operation", "id", "max_events"], inplace=True)
#            offset length   start_time     end_time  nprocs  container run
# 68430   150888123   3590   827.266229   827.266251      16  apptainer   1
# 107463  293401409   3524  1605.625702  1605.625725      16  apptainer   1
# 121655  343876585   3580  1882.030412  1882.030435      16  apptainer   1
# 55597   105592334   3496   583.815295   583.815319      16  apptainer   1
# 52884    96083791   3498   522.155999   522.156025      16  apptainer   1
# ...           ...    ...          ...          ...     ...        ...  ..
# 2697      8162866   3360  5920.526680  5920.526733       8     podman   1
# 2698      8166226   3360  5920.526736  5920.526778       8     podman   1
# 2699      8169586      0  5920.526781  5920.526782       8     podman   1
# 2700      8169586   1597  5920.526791  5920.526813       8     podman   1
# 2701      8171183      0  5920.526816  5920.526817       8     podman   1
#
# [23860889 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

df = darshan_data_frames[(darshan_data_frames["nprocs"] >= 8) & (darshan_data_frames["nprocs"] < 128)]
plot = sb.lineplot(data=df, x="start_time", hue="nprocs")
# Out:
#   Cell In[5], line 5
#     plot = sb.lineplot(data=df, x="start_time", bins=, hue="nprocs")
#                                                      ^
# SyntaxError: invalid syntax
